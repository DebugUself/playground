# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('0701_06.csv')
df1
# Out:
#    cost    py  read   eco  play   pyb   gf  fit
# 0  63.0   0.0   2.8   0.0   7.6  13.4  8.7  4.4
# 1  53.6   0.0   3.5  28.2  11.0   0.0  3.7  0.0
# 2  56.4   9.4   6.5  11.8   4.3   0.9  4.2  6.5
# 3  77.5   0.0   7.2   0.0   5.9   0.0  4.9  4.6
# 4  65.5  14.2   0.0  10.2   3.1   1.0  2.9  3.1
# 5  77.5   0.0   7.2   0.0   5.9   0.0  4.9  4.6

# %% [markdown]
# ### 计算: 相加

# %%
df1['cost + eco'] = df1['cost'] + df1['eco']  
df1['py + pyb'] = df1['py'] + df1['pyb']
df1['read + play + gf'] = df1['read'] + df1['play'] + df1['gf']
df1
# Out:
#    cost    py  read   eco  play   pyb   gf  fit  cost + eco  py + pyb  \
# 0  63.0   0.0   2.8   0.0   7.6  13.4  8.7  4.4        63.0      13.4
# 1  53.6   0.0   3.5  28.2  11.0   0.0  3.7  0.0        81.8       0.0
# 2  56.4   9.4   6.5  11.8   4.3   0.9  4.2  6.5        68.2      10.3
# 3  77.5   0.0   7.2   0.0   5.9   0.0  4.9  4.6        77.5       0.0
# 4  65.5  14.2   0.0  10.2   3.1   1.0  2.9  3.1        75.7      15.2
# 5  77.5   0.0   7.2   0.0   5.9   0.0  4.9  4.6        77.5       0.0
#
#    read + play + gf
# 0              19.1
# 1              18.2
# 2              15.0
# 3              18.0
# 4               6.0
# 5              18.0

# %% [markdown]
# ### selection: columns

# %%
# 参考p401 pandas 0.20.2
df2 = df1.iloc[:,7:11]
df2
# Out:
#    fit  cost + eco  py + pyb  read + play + gf
# 0  4.4        63.0      13.4              19.1
# 1  0.0        81.8       0.0              18.2
# 2  6.5        68.2      10.3              15.0
# 3  4.6        77.5       0.0              18.0
# 4  3.1        75.7      15.2               6.0
# 5  4.6        77.5       0.0              18.0

# %%
# 参考p113 PDSH2017
df3 = df1.loc[:,'fit':'read + play + gf']
df3
# Out:
#    fit  cost + eco  py + pyb  read + play + gf
# 0  4.4        63.0      13.4              19.1
# 1  0.0        81.8       0.0              18.2
# 2  6.5        68.2      10.3              15.0
# 3  4.6        77.5       0.0              18.0
# 4  3.1        75.7      15.2               6.0
# 5  4.6        77.5       0.0              18.0

# %% [markdown]
# ### [失败案例] 日期做index

# %%
index=pd.date_range('2017/06/26', periods=5, freq='B')

# %%
df_x = pd.DataFrame(pd.read_csv('0701_06.csv'), index=index)
df_x
# Out:
#             cost  py  read  eco  play  pyb  gf  fit
# 2017-06-26   NaN NaN   NaN  NaN   NaN  NaN NaN  NaN
# 2017-06-27   NaN NaN   NaN  NaN   NaN  NaN NaN  NaN
# 2017-06-28   NaN NaN   NaN  NaN   NaN  NaN NaN  NaN
# 2017-06-29   NaN NaN   NaN  NaN   NaN  NaN NaN  NaN
# 2017-06-30   NaN NaN   NaN  NaN   NaN  NaN NaN  NaN

# %% [markdown]
# ### 作图: ggplot

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
df2 = df2.cumsum()

# %%
plt.figure()
df2.plot()
plt.show()

# %% [markdown]
# # 经验教训
#
# 1. 百分比不好
# 2. 手动不好
# 3. 使用秒数最大化差异
