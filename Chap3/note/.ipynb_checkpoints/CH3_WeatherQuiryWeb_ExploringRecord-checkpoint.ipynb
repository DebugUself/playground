# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#CH3-天气查询-Web-程序" data-toc-modified-id="CH3-天气查询-Web-程序-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>CH3 天气查询 Web 程序</a></div><div class="lev2 toc-item"><a href="#Task" data-toc-modified-id="Task-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Task</a></div><div class="lev3 toc-item"><a href="#Basic-Task" data-toc-modified-id="Basic-Task-111"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Basic Task</a></div><div class="lev3 toc-item"><a href="#Advance-Task" data-toc-modified-id="Advance-Task-112"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Advance Task</a></div><div class="lev2 toc-item"><a href="#Think" data-toc-modified-id="Think-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Think</a></div><div class="lev2 toc-item"><a href="#Action" data-toc-modified-id="Action-13"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Action</a></div><div class="lev3 toc-item"><a href="#00-flask-的-Hello-World" data-toc-modified-id="00-flask-的-Hello-World-131"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>00 flask 的 Hello World</a></div><div class="lev3 toc-item"><a href="#01-app-整体文件结构" data-toc-modified-id="01-app-整体文件结构-132"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>01 app 整体文件结构</a></div><div class="lev3 toc-item"><a href="#02-编写-html-页面" data-toc-modified-id="02-编写-html-页面-133"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>02 编写 html 页面</a></div><div class="lev3 toc-item"><a href="#03-HTML-用户页面与-Flask-服务器的数据交互" data-toc-modified-id="03-HTML-用户页面与-Flask-服务器的数据交互-134"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>03 HTML 用户页面与 Flask 服务器的数据交互</a></div><div class="lev3 toc-item"><a href="#04-基本功能实现(尝试1)" data-toc-modified-id="04-基本功能实现(尝试1)-135"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>04 基本功能实现(尝试1)</a></div><div class="lev3 toc-item"><a href="#05-jinja2-模板的使用" data-toc-modified-id="05-jinja2-模板的使用-136"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>05 jinja2 模板的使用</a></div><div class="lev4 toc-item"><a href="#jinja2-小探" data-toc-modified-id="jinja2-小探-1361"><span class="toc-item-num">1.3.6.1&nbsp;&nbsp;</span>jinja2 小探</a></div><div class="lev4 toc-item"><a href="#jinja与-server-端配置" data-toc-modified-id="jinja与-server-端配置-1362"><span class="toc-item-num">1.3.6.2&nbsp;&nbsp;</span>jinja与 server 端配置</a></div><div class="lev4 toc-item"><a href="#模板传递变量的-MVP-具体实现过程" data-toc-modified-id="模板传递变量的-MVP-具体实现过程-1363"><span class="toc-item-num">1.3.6.3&nbsp;&nbsp;</span>模板传递变量的 MVP 具体实现过程</a></div><div class="lev3 toc-item"><a href="#06-基本功能实现(尝试2)" data-toc-modified-id="06-基本功能实现(尝试2)-137"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>06 基本功能实现(尝试2)</a></div><div class="lev3 toc-item"><a href="#07-CSS-美化页面" data-toc-modified-id="07-CSS-美化页面-138"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>07 CSS 美化页面</a></div><div class="lev3 toc-item"><a href="#07-WEB-应用适配移动端" data-toc-modified-id="07-WEB-应用适配移动端-139"><span class="toc-item-num">1.3.9&nbsp;&nbsp;</span>07 WEB 应用适配移动端</a></div><div class="lev2 toc-item"><a href="#KeyPoint" data-toc-modified-id="KeyPoint-14"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>KeyPoint</a></div><div class="lev2 toc-item"><a href="#CommandSet" data-toc-modified-id="CommandSet-15"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>CommandSet</a></div><div class="lev2 toc-item"><a href="#Question" data-toc-modified-id="Question-16"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Question</a></div><div class="lev2 toc-item"><a href="#Timelog" data-toc-modified-id="Timelog-17"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Timelog</a></div>

# %% [markdown]
# # CH3 天气查询 Web 程序

# %% [markdown]
# ## Task
#
# ### Basic Task
#
# -  内网可用的天气查询程序(web)
#     - 基本功能
#         - 输入城市名，返回该城市最新的天气数据；
#         - 点击帮助,获取帮助信息
#         - 点击历史,获取历史查询信息
# - 部署在命令行界面
#
# ### Advance Task
#
# - web应用适配移动端

# %% [markdown]
# ## Think

# %% [markdown]
# - 00 简单了解 web 开发与 web 框架
#     - web 开发: 相对桌面客户端 Client/Server的CS 架构,更容易修改与升级的 browser/server模式的 BS 架构
#     - web 框架:向程序员隐藏了处理 http 请求和响应相关的基础代码
#         - pytho的两个代表框架
#             - Django
#             - Flask
# - 01 flask 的 Hello word
#     - route 路由: url 与 func 的连接器,而 url -> 特定的 html 页面
#     - 2Q:
#         - html 如何建立?
#         - py 与 html 乃至 template 的关系如何?组织结构?连接形式?
#
# - 02 app 的文件组织形式应该是怎么样的?
#     - 观察同学作业
#     - github 的 flask 项目
# - 03 构建基本的 html 页面
#     - client -点击[按钮]/链接,输入[表单] page ->[http] ->server

# %% [markdown]
# ## Action

# %% [markdown]
# ### 00 flask 的 Hello World
#
# - **0 flask 安装**
#     - 00 基本概念
#         -  [WSGI(Web Server Gateway Interface)](https://en.wikipedia.org/wiki/Web_Server_Gateway_Interface#WSGI_and_Python_3)
#             - python 编程语言中,web服务器与web应用程序/框架的简单接口规范,初始于2003发布为 PEP 333,最新适应 python3的版本为 PEP 3333
#         -  Werkzeug:WSGI 的工具包
#         -  [Jinja2](http://jinja.pocoo.org/):渲染模板
#     - 01 PY3 的使用注意
#         - py>3.2
#         - latest versions of all Flask-related packages
#             - Flask 0.10 and Werkzeug 0.9
#     - 02 安装
#         - 0 pip/virtualenv
#             + 由于已经是使用了包管理工具anaconada3, 再安装virtualenv会报错
#         - 1 anaconda3
#             + `conda list` => 查看预装包列表
#                 * flask  0.12.2  py36_0
#             + `conda update flask`=> 已是最新
# - **1 flask mvp:Hello World**
#     - =>[Quickstart — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/quickstart/)
#     - 00 编辑hello world脚本:
#         * WeatherQueryWebAPP_Flask.py
#         * 不要用直接用 FLask.py 命名, 会造成混乱
#     - 01 设置环境变量:FLASK_APP environment variable
#         - FLASK_APP
#         - FLASK_DEBUG
#   ***
#     ```python
#     # 00 WeatherQueryWebAPP_Flask.py
#     from flask import Flask  #引入 flask 类
#     app = Flask(__name__)  #该类的一个示例就是WSGI交互程序
#
#     @app.route('/')  #告诉 flask 什么样的 url 可以触发函数
#     def hello_world() :  #函数名用于生成url,并返回想要呈现在用户浏览器的信息
#         return "Hello,World!"
#     ```
#     ***
#     ```python
#     # 01 Terminal
#     $ export FLASK_APP=WeatherQueryWebAPP_Flask.py # 设置启动的 app 名称
#
#     $ export FLASK_DEBUG=1 #开启调试模式
#     ```
#     ***
#     - 02 运行本地服务器
#         - `notes`:
#
#     ```
#     $ flask run
#     ```
#
#     - 03 在浏览器运行 `http://127.0.0.1:5000/`
#          - Hello World 成功~

# %% [markdown]
# ### 01 app 整体文件结构
#
# - 方向
#     - 学友的代码/教程
#     - github 上基于 flask 的项目
# - 参考
#     - [Py103@Yifan127目录结构 ](https://github.com/AIHackers/Py101-004/tree/master/Chap3/resource/web0_project_Yifan127)
#     - [Py104@Hugo1030目录结构_ ](https://github.com/Hugo1030/Py101-004/tree/master/Chap3/project)
#     - [Py104@JeetChan笔记](https://github.com/JeetChan/Py101-004/blob/master/Chap3/note/chap3_note.md#%E9%A1%B9%E7%9B%AE%E6%96%87%E4%BB%B6%E7%BB%93%E6%9E%84)
#     - [flask/examples/flaskr](https://github.com/pallets/flask/tree/master/examples/flaskr/flaskr)
#     - [flask-website/flask_website](https://github.com/pallets/flask-website/tree/master/flask_website)
# -  结论
#     - 基于本次任务的推荐结构
#         - => [Py104@JeetChan笔记](https://github.com/JeetChan/Py101-004/blob/master/Chap3/note/chap3_note.md#%E9%A1%B9%E7%9B%AE%E6%96%87%E4%BB%B6%E7%BB%93%E6%9E%84)
#         ```
#         project <-- 根目录
#            ├─static  <-- 存放静态文件
#            │  ├─css
#            │  ├─img
#            │  └─js
#            ├─templates <-- 存放模板文件
#            |  └─.html
#            ├─...<other file>
#            └─app.py
#        ```
#     - 可扩展的方向
#         - => [flask-website/flask_website](https://github.com/pallets/flask-website/tree/master/flask_website)

# %% [markdown]
# ### 02 编写 html 页面
#
# - 0 py 脚本如何调用 html 页面?
#     - =>[Quickstart — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/quickstart/#rendering-templates)
#     - flask 使用 render_template 方法
#         - `return render_template('HelpInfo.html')`
# - 1 html 包含哪些元素?如何进行编辑?
#     - 页面标记语言
#         - =>[HTML & CSS - W3C](https://www.w3.org/standards/webdesign/htmlcss)
#         - 标记语言构建页面.
#             - 由 ` Element ` 构成
#             - 由 ` Tag ` 实现
#         - 各种标记(`tag`)见=>[HTML 元素参考 - HTML（超文本标记语言） | MDN](https://developer.mozilla.org/zh-CN/docs/Web/HTML/Element)
#         - html => 页面构成
#         - css => 样式渲染
#         - JavaScript => 动态效果
#
# - 2 构建页面尝试
#     - __Q:__
#         - 需要构建哪些页面?
#             - Index=>1个界面即可.
#         - 页面需要哪些元素?
#             - 标题
#             - 输入框
#             - 按钮
#             - 信息展示区
#         - 元素与后端如何联系?
#             - form元素 与 @route 装饰器通过 http 协议(url变化)进行交互
#         - 元素间如何布局组织?[w]
# - 3 成果
#
#
# ```html
#
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>WeatherQuery</title>
# 	<meta charset="utf-8">
# </head>
# <body>
# 	<h1>WeatherQuery</h1>
# 	<p>Welcome!</p>
# 	<p>Please input the city name</p>
#
# 	<div>
# 		<form action="commond" method="GET">
# 			<label for="city">指令:</label>
# 			<input type="text" name="city">
# 			<input type="submit" value="提交">
# 		</form>
# 	</div>
#
# </body>
# </html>
#
# ```

# %% [markdown]
# ### 03 HTML 用户页面与 Flask 服务器的数据交互
#
# - **目标**:服务端对客户提交的输入框内容进行响应,返回显示相应内容
#     - 如:输入"0",返回"1"
# - **原理**:该目标涉及 html 页面 与 flask server 交互的原理, 二者通过 http 协议进行交互,即 url 的变化进行交互,具体过程如下:
#     - 0 html 用[form](https://developer.mozilla.org/zh-CN/docs/Web/HTML/Element/form)元素来向web服务器提交信息,其 action 属性会修改 url
#     ```html
#     <!-- 一个简单的表单，这个表单会发送一个 GET 请求 -->
#     <form action="commond" method="GET">
#         <label for="city">指令:</label>
#         <input type="text" name="city">
#         <input type="submit" value="提交">
#     </form>
#     ```
#     - 1 当在输入框输入内容"0",并回车提交时,可以观察到 url 的变化如下:
#         > index 页面初始 url: http://127.0.0.1:5000/
#         >
#         > input 提交后的 url:http://127.0.0.1:5000/commond?city=0
#     - 2 根据 url 的变化,我们在 py 脚本中用 @route 进行捕捉,关联相关操作函数:
#     ```python
#     @app.route('/commond')
#     def query_func():
#         return "1"
#     ```
#     - 3 进一步, flask 提供 [request.args.get('key', '')](http://flask.pocoo.org/docs/0.12/quickstart/#the-request-object)为我们获取用户输入的变量数据
#     ```python
#     @app.route('/commond')
#     def query_func():
#         searchword = request.args.get('city', '')
#         return searchword
#     ```
# - **总结**:通过 html 的 form 元素与 flask 的  @route 装饰器,网页客户端与服务器端接可以根据http 协议(url 变化)来实现查询信息的交互.
# - **修正**:经过更深入的探索,发现当发送 requests 的方法为 get 的时候, url 才会包含变化的变量,而使用 post 的方法时,变量变化不会体现在 url 上.而且无论 html 页面中设置的是 get 还是 post方法 ,server 的路由设置的接受方法最好两种皆包含,否则容易出现405错误:该方法不被接受.
#     ```python
#     @app.route("/", methods=['POST', 'GET'])
#     ```

# %% [markdown]
# ### 04 基本功能实现(尝试1)
#
# - 0 前提: html 页面与 flask 后台已经接通,输入0,返回0
# - 1 进行命令判断分流
#     - 1.1 如果输入的内容在 ('h', 'help', 'history', 'q', 'quit')中,执行命令
#     - 1.2 如果输入的内容不在其中,进行 api 查询
#         - 如果有天气数据返回,则 返回天气
#         - 如果404,提示用户修改命令,或者无该城市天气信息
# - X 从命令行到 web开发的区别是,返回的不再是字符串,而是 html 页面,如果想实现特定信息回传,需要使用模板.
#
# - 重要参考:
#     - ```
#     from flask import Flask, render_template, request
#
#     app = Flask(__name__)
#
#     @app.route('/', methods=['GET', 'POST'])
#     def form():
#         return render_template('form.html')
#
#     @app.route('/hello', methods=['GET', 'POST'])
#     def hello():
#         return render_template('greeting.html', say=request.form['say'], to=request.form['to'])
#
#     if __name__ == "__main__":
#         app.run()
#
#     ```
#
# - 0 目标: 按下 help 按钮,返回 help.html
# - 1 解答:
#     - 利用 form 的 action 属性,与路由配合实现基本功能,通过浏览器显示对应的天气情况、历史查询信息和帮助文档:
#         action="query" => '天气'
#         action="history" => history.html
#         action="help" => help.html
# - 2 缺陷:
#     - 每个 HTML 页面相同部分代码都需复制
#     - 读取历史信息无法传递变量,十分麻烦
#     - 路由下的函数似乎无法传递变量
#
# => 转换方向 :使用模板实现基本功能,
#     - 返回的某个变量可能每次都不同
#     - 而其它页面内容保持不变，这时可以通过网页模板，方便快捷地达到目的。

# %% [markdown]
# ### 05 jinja2 模板的使用
#
# #### jinja2 小探
#
# - 0 为什么要使用模板引擎
#     - Q: 模板的使用对原始的 JS 与 HTML 配合 有什么优势呢?
#         - => [作为一名前端的你,必须掌握的模板引擎:Handlebars - 简书](https://www.jianshu.com/p/2ad73da601fc)
#         - => [知乎 Niko 的回答](https://www.zhihu.com/question/21893022/answer/19647087)
#         > 模板最本质的作用是 **【变静为动】**
#         >一切利用这方面的都是优势，不利于的都是劣势。要很好地实现【变静为动】的目的，有这么几点：
#
#             >1.可维护性（后期改起来方便）；
#
#             >2.可扩展性（想要增加功能，增加需求方便）；
#
#             >3.开发效率提高（程序逻辑组织更好，调试方便）；
#
#             >4.看起来舒服（不容易写错）；
#
#         >从以上四点，你仔细想想，前端模板是不是无论从哪方便优势体现都不是一点两点。其实最重要的一点就是：**【视图（包括展示渲染逻辑）与程序逻辑的分离】**
#         > 分离的好处太多了，更好改了，更好加东西了，调试也方便了，看起来也舒服了，应用优秀的开发模式更方便了（mvvc，mvc等），是吧
#     - 小结: 模板实现了 **视图逻辑与程序逻辑的分离**,变静为动
#
# - 1 为什么要使用 jinja? 他有什么功能?
#     - a full featured template engine for Python
#     - 一个 python 的全功能模板引擎
#         > sandboxed execution 沙盒执行
#
#         > powerful automatic HTML escaping system for XSS prevention 强大的XSS预防自动HTML转义系统
#
#         > template inheritance 模板继承
#
#         > compiles down to the optimal python code just in time 及时编译到最佳的Python代码
#
#         > optional ahead-of-time template compilation 可选的提前模板编译
#
#         > easy to debug. Line numbers of exceptions directly point to the correct line in the template. 容易调试,有明确的行号指向.
#
#         > configurable syntax 可配置的语法
#
# - 2 寻找 Jinja2 使用资料 ?
#     - Q 如何查找 jinja2 的使用方法?
#     - A 查看官方文档,先看介绍,发现应当先安装 jinja2 模块
#         - Q 如何得知当前 python 所有安装模块? 从而确认 jinja2 已经安装?
#         - A 搜索google
#             - => [查看python已安装模块的方法小结 - CSDN博客](http://blog.csdn.net/healthy_coder/article/details/50546384)
#             - => 命令行中运行 `$ pydoc modules`
#         - A 在命令行中运行 `$ pydoc modules`,
#             - => 显示所有已安装模块,确认 jinja2 已经安装
#     - A 使用官方文档 Quick search 功能,搜索 `flask`
#         - => [Template Designer Documentation — Jinja2 Documentation (2.10)](http://jinja.pocoo.org/docs/2.10/templates/)
#         - => 快速浏览,确认其对 jinja2 使用介绍很详尽,资料靠谱,深入钻研.
#
# - 3 jinja2 必要认识 | 摘要
#     - 小结
#         - jinja 本质上是一个文本文件,无需额外扩展名
#         - 4种分隔符的形式与作用
#
#     - 原文
#     - A Jinja template is simply a text file. Jinja can generate any text-based format (HTML, XML, CSV, LaTeX, etc.). A Jinja template doesn’t need to have a specific extension: .html, .xml, or any other extension is just fine.
#         - jinja 本质上是一个文本文件,可以生成任意文本类格式(HTML, XML, CSV, LaTeX, etc.),一个 jinja 模板不需要特殊的文件扩展名,.html,.xml,或其他扩展名皆可.
#     - A template contains variables and/or expressions, which get replaced with values when a template is rendered; and tags, which control the logic of the template. The template syntax is heavily inspired by Django and Python.
#         - 一个模板包含 **变量** 和/或 **表达式**,以此来指代渲染后的具体的值;以及 **便签**,控制模板的逻辑.模板的语法受 Django 与 python 的启发相当深.
#     - Below is a **minimal template** that illustrates a few basics using the default Jinja configuration. We will cover the details later in this document:
#         - **最小模板**,显示了默认 jinja 配置的一些基本用法.
#
#         ```html
#         <!DOCTYPE html>
#         <html lang="en">
#         <head>
#             <title>My Webpage</title>
#         </head>
#         <body>
#             <ul id="navigation">
#             {% for item in navigation 项目定位 %}
#                 <li><a href="{{ item.href 项目链接 }}">{{ item.caption 项目标题}}</a></li>
#             {% endfor %}
#             </ul>
#
#             <h1>My Webpage</h1>
#             {{ a_variable 一个变量 }}
#
#             {# a comment 一条注释 #}
#         </body>
#         </html>
#         ```
#
#     - The following example shows the default configuration settings. An application developer can change the syntax configuration from {% foo %} to <% foo %>, or something similar.
#         - 以下的例子显示了默认的设置.应用开发者可以改变语法设置,如 从{% foo %} 到 <% foo %> ,或其他类似情况.
#
#     - There are a few kinds of delimiters. The default Jinja delimiters are configured as follows:
#         - 这里是一些分隔符, jinja 默认分隔符 配置如下
#
#     - {% ... %} for Statements
#         - 声明
#     - {{ ... }} for Expressions to print to the template output
#         - 表达式打印在模板输出
#     - {# ... #} for Comments not included in the template output
#         - 未包含在模板输出的注释
#     - \#  ... ## for Line Statements
#         - 行注释
#
# #### jinja与 server 端配置
#
# - Q jinja 的使用需要在 html 以及server上做设置,html 基本清晰,那么 sever 端 的 py 脚本应该做何改动?如何与 html 文件配合?
#     - A 快速浏览文档,寻求 server 端代码
#     - X 未果
#     - A 那么先试用, 第一次尝试建立MVP:将py 脚本设定的变量值显示在 html 中
#         - Q 如何引入模板?
#             - A 查找介绍
#             - O `from jinja2 import Template`
#         - Q 如何传递变量?
#             - A 建立一个测试变量 `Test_v = "测试"`
#             - A 向 html页面 添加 `{{ a_variable 一个变量 }}`
#             - X 失败,但是搜索过程发现参考文档使用错误
#     - O 在建立 MVP 的过程中找到 server 端示例代码
#         - => [Introduction — Jinja2 Documentation (2.10)](http://jinja.pocoo.org/docs/2.10/intro/#basic-api-usage)
#
#         ```bash
#          from jinja2 import Template
#          template = Template('Hello {{ name }}!')
#          template.render(name='John Doe')
#
#         ```
#     - X 无法顺利建立 MVP,第一次建立 MVP 失败
#         - Q 这个代码段显示了在命令行中,变量到具体 jinja 语句的实现,但是 目标语句所在的 html 文件应该如何指定呢?
#         - Q 即 jinja 如何在服务端定向到 html 文件?
#             - A 官方文档快速搜索 "HTML"
#             - O => [API — Jinja2 Documentation (2.10)](http://jinja.pocoo.org/docs/2.10/api/)
#                 - A 快速扫视摘要
#                 - O 这份文档是为实现模板与应用交互而非创造 jinja2 模板提供参考,定位成功.
#                     - It will be most useful as reference to those implementing the template interface to the application and not those who are creating Jinja2 templates.
#             - A 细读 [API — basic 部分](http://jinja.pocoo.org/docs/2.10/api/#basics)
#                  ```python
#                 from jinja2 import Environment, PackageLoader, select_autoescape
#                 env = Environment(
#                     loader=PackageLoader('yourapplication', 'templates'),
#                     autoescape=select_autoescape(['html', 'xml'])
#         )
#                 ```
#         - O 通过精读可得3段示例代码,分别实现了
#             - 设置模板环境
#             - 对位模板
#             - 传递指定变量的功能
#             - => 详见 MVP 建立部分
#
# - 4 jinja2 API basic 精读
#     - Jinja2 uses a central object called the template **Environment**. Instances of this class are used to store the configuration and global objects, and are used to load templates from the file system or other locations. Even if you are creating templates from strings by using the constructor of Template class, an environment is created automatically for you, albeit a shared one.
#         - jinja2 使用名为 Environment 的主对象.这个类的实例被用作储存配置与全局对象,从文件系统或其他位置加载模板.即使你通过模板类的构建函数,正使用字符串创建模板,也会自动为你创建一个共享的 environment
#     - Most applications will create one Environment object on application initialization and use that to load templates. In some cases however, it’s useful to have multiple environments side by side, if different configurations are in use.
#         - 当应用初始化时,大多数应用将创造一个 Environment 对象用以加载模板.但是有一些例外情况,如果不同的配置正在被使用,有多个环境并行是有益的.
#     - The simplest way to configure Jinja2 to load templates for your application looks roughly like this:
#         -  MVP: 为你的应用配置  jinja2 以加载模板最简单的方式
#
#         ```python
#         from jinja2 import Environment, PackageLoader, select_autoescape
#         env = Environment(
#             loader=PackageLoader('yourapplication', 'templates'),
#             autoescape=select_autoescape(['html', 'xml'])
#         )
#         ```
#
#     - This will create a template environment with the default settings and a loader that looks up the templates in the templates folder inside the your application python package. Different loaders are available and you can also write your own if you want to load templates from a database or other resources. This also enables autoescaping for HTML and XML files.
#         - 这将创建一个默认配置的模板环境以及一个加载器来在你应用之 python 包内的模板文件夹查找相应模板.可以使用不同的装载器，如果要从数据库或其他资源加载模板，也可以编写自己的装载器。这也可以为HTML和XML文件自动转义。
#         - Q **自动转义是什么?有何用途?**
#     - To load a template from this environment you just have to call the get_template() method which then returns the loaded Template:
#         - 你只需调用  `get_template()` 方法就可以返回加载的模板
#         ```python
#         template = env.get_template('mytemplate.html')
#         ```
#
#     - To render it with some variables, just call the render() method:
#         - 只需调用 `render()`方法来带变量渲染模板:
#         ```python
#         print template.render(the='variables', go='here')
#         ```
#
#     - Using **a template loader** rather than passing strings to Template or Environment.from_string() has multiple advantages. Besides being a lot easier to use it also enables template inheritance.
#         - 使用 模板加载器 比传递字符串到模板或者使用`Environment.from_string()`更具优点.除了更易用,还利于模板的继承.
#         - Q **什么是 模板的继承?**
#
#     - Notes on Autoescaping
#
#     - In future versions of Jinja2 we might enable autoescaping by default for security reasons. As such you are encouraged to explicitly configure autoescaping now instead of relying on the default.
#         - 在 jinja2的未来版本中,出于安全考虑,我们可能默认实现自动转义.
#         - 因此，鼓励您现在显式配置自动转义，而不是依赖于默认值。
#
# #### 模板传递变量的 MVP 具体实现过程
#
# - 5 jinja 模板 MVP 实现
#     - I 精读 API 文档,获得如下表达式:
#         - 配置模板环境
#             ```python
#             from jinja2 import Environment, PackageLoader, select_autoescape
#             env = Environment(
#                 loader=PackageLoader('yourapplication', 'templates'),
#                 autoescape=select_autoescape(['html', 'xml'])
#             )
#             ```
#         - 返回加载的模板
#             ```python
#             template = env.get_template('mytemplate.html')
#             ```
#         - 带变量渲染模板
#
#             ```python
#             print template.render(the='variables', go='here')
#             ```
#     - A 第二次 mvp: 将测试变量 name=倪必荣 传递到 index.html 上指定位置
#         - A 服务端设置
#             ```python
#             from jinja2 import Environment, PackageLoader, select_autoescape
#
#             app = Flask(__name__)  #该类的一个示例就是WSGI交互程序
#
#             env = Environment(
#                 loader=PackageLoader('app', 'templates'),
#                 autoescape=select_autoescape(['html', 'xml'])
#             )
#
#             @app.route('/')  #告诉 flask 什么样的 url 可以触发函数
#             def index_func() :      #函数名用于生成url,并返回想要呈现在用户浏览器的信息
#                 template = env.get_template('Index.html')
#                 print template.render(the='倪必荣', go='name')
#                 return render_template('Index.html')
#             ```
#         - A Index.html设置
#             - `<body>`中添加
#             ```html
#             	{{name}}
#             ```
#         - A 调试
#             - X Print 格式错误
#                 - A print 后的内容加上括号
#                 - O 解决
#             - X ModuleNotFoundError: No module named 'app'
#                 - A  修改 app 为 py文件所在高级路径名 'project'
#                 - X 错误
#             - X ModuleNotFoundError: No module named 'project'
#                 - Q 试着重新理解,调用模块, py脚本在运行,或许只需调用模板文件夹即可?
#                     - A 修改`loader=PackageLoader('project', 'templates')`为
#                         - `loader=PackageLoader('templates')`
#                     - X 错误
#             - X NotImplementedError: Can't perform this operation for unregistered loader type
#                 - I 由于转载机未注册无法执行这个操作
#                 - A Google : `jinja2 NotImplementedError: Can't perform this operation for unregistered loader type`
#                 - O => [Stack Overflow](https://stackoverflow.com/questions/37069303/notimplementederror-cant-perform-this-operation-for-unregistered-loader-type)
#                     - A 确认其问题与所求相符合
#                     - A 根据建议, 在 project 目录下兴建一个`__ init__.py` 的空白文件
#                     - O 成功显示 index 界面
#             - X 但是没有看到变量
#                 - Q 对代码的变量使用存在哪些误解?
#                 - A 重看实例代码
#                     ```bash
#                      template = Template('Hello {{ name }}!')
#                      template.render(name='John Doe')
#                     ```
#                 - O 等号前与变量名,等号后是具体传递的变量
#                 - A 修改 `print (template.render(the= 'nibirong', go='name'))`为
#                     - `print (template.render(name=' 倪必荣'))`
#                 - X 变量依然未出现
#                     - Q 或许加载的是原始的未经 jinja 改变的模板? 该如何调用修改后的模板?
#                     - A 重新审视 3段示例代码
#                     - A 修改`return render_template('Index.html')`为
#                         - `return render_template(template)`
#                     - X 无效,变量依然无法传递
#                     - A 重新梳理一遍问题的解决过程
#                     - X 没有发现
#                     - A 查看 py103 自己的实现过程
#                     - O 原来是使用render_template("quote.html",info=noneInfo)来实现的
#                         - 是了 flask 是采用了 jinja2 ,说明包含了 jinja2的功能,在 flask 模块必然有某个模块设计调用了 jinja2 的 kpi,然后重新设计了调用形式
#                     - A 在 flask 官方文档中搜索 `jinja2`
#                     - W 意外收获,发现了[Tutorial — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/tutorial/),从头到尾建立一个可行的 flask 应用 ,包括测试,基础任务实现后可以一试.
#                     - A 使用render_template(传递)变量
#                         - return render_template(template,name="倪必荣")
#             - O 调试成功
#         - O MVP 完成:
#             - O 额外体会 : 资料优先级
#                 - 对象优先级: 直接使用>间接依赖(Flask> jinja)
#                 - 文档优先级:
#                     - 标题>代码>正文
#                     - 总体说明脉络 > 各部分细致介绍
#                     - Quickstart > Tutorial >  QA > 其他
#                 - 搜索优先级
#                     - 英文>中文
#                     - 官方文档>Google
#                     - 开始时快速浏览几个文档 > 直接深入钻研一个文档
#                 - 本次实例资料具体优先级
#                     - [Quickstart — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/quickstart/)
#                     - [Tutorial — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/tutorial/)
#                     - jinja2 QuickSearch
#     - O 第二次尝试建立 MVP 成功

# %% [markdown]
# ### 06 基本功能实现(尝试2)
#
# - Q 需要实现哪些基本功能?
#     - 帮助
#     - 查询历史
#     - 天气查询
# - Q 当前有哪些想法与思路?
#     - 基于 MVP 已经建立:
#         - html => py(flask): 通过表单 `<form>` 接收用户查询信息
#         - py(flask) => html: 通过模板渲染显示服务器处理的的信息
#     - 因此梳理信息传递流程,进行信息与函数的封装:
#         ```
#         - [浏览器]用户        => HTML : `<form>`表单  =>  HTTP 协议 => Server: app.py(flask)
#         -  +-输入信息
#         -  +-点击按钮
#         ```
#     - 由易到难,实现顺序:
#         - 帮助
#         - 查询
#         - 历史
# - Q 如何实现功能1: 帮助?
#     - A 先梳理基本操作,将原来设计的3个 html 删除,只用一个 Index.html 来处理
#     - A 设置好 html 的 `<form>` 以及 模板变量:
#         - NOTE: 代码中`{/{` 为`{{`
#     ```html
#     	<div>
# 		<form action="query" method="GET">
# 			<label for="city">城市:</label>
# 			<input type="text" name="city">
# 			<input type="submit" name="history" value="历史">
# 			<input type="submit" name="help" value="帮助">
#         </div>
#         <p>{/{ DisplayInfo }}</p>
#     ```
#
#     - A 设置对应路由的执行函数
#         - Q 路由如何捕捉 html 发送的 request中的key?
#             - A Flask 文档 快速搜索 `request` =>[the-request-object](http://flask.pocoo.org/docs/0.12/quickstart/#the-request-object)
#             - O `request.form.keys()`
#             - O 模块存在层级关系:
#                 - request/form/keys:values
#         - A 设置执行函数如下:
#         ```python
#         @app.route('/')
#         def index_func(DisplayInfo=None) :
#             if 'help' in request.form.keys():
#                 return render_template('Index.html',DisplayInfo="help_info")
#             else:
#                 return render_template('Index.html',DisplayInfo="Hello World!")
#         ```
#     - X hello_world 可以显示, help_info 不行
#         - I 错误提示:405 Method Not Allowed
#         - A 试着改变路由的接受方式:
#             - py:`@app.route('/')`=> `@app.route('/',methods=["POST","GET"])`
#             - html:`<form action="/" method="get">`=>`<form action="/" method="post">`
#         - O 成功运行,点击 help 按钮成功显示 help_info
#     - A 将 help_info 用实际的 help_func 取代
#         - A 查找 ch2的 help_func
#         - X 太过复杂,算了
#         - A 直接重写 help_info
#         ```python
#                 help_info='''
#         Tips:
#             - 输入要查询的城市名称,回车确认将返回即时天气信息
#             - 点击"help"按钮,显示帮助信息
#             - 点击" history"按钮,显示查询历史
#         '''
#                 return render_template('Index.html',DisplayInfo=help_info)
#
#         ```
#         - X 显示的帮助信息没有分行
#             - A 在末尾加上分行符 `/n`
#             - X 无效
#             - I 可能是 `<p>` 便签的缘故
#                 - A 去掉 `<p>` 便签
#                 - X 不行
#                 - A 试着用`<br>` 或者`</br>`分行
#                 - X 依然无效,可能被当做字符内容处理掉了
#                 - A 试着用 jinja2 模板
#                 - X 未找到方法
#                 - A 观摩 py103 的实现方法
#                 - O Html 的`<pre>`标签,可以显示预先格式化的文本
#         - O 使用`<pre>`标签可以显示预格式文本
#     - O 功能1: 点击按钮,返回帮助信息 完成.
#     - A 将 帮助信息 函数化,方面以后帮助信息的修改,不影响到主运行函数的运行
#     - O 完成
#
# - Q 如何实现查询功能
#     - I ch2 已实现的 API,进行复用
#     - Q 如何复用 ch2 的 API?需要导入哪些模块?
#         - A 观察 API 代码,将 util 文件夹 与 API_deal.py ,weather_query_API.py 由 ch2 复制到 ch3 中
#         - A 寻找主程序对 api 的调用,进行模仿
#         - O 结果如下
#         ```python
#         import API_deal
#
#         history_list = []
#         command_tuple = ('h', 'help', 'history', 'q', 'quit')
#         unit_switch_tuple = ('c', 'f')
#         API_tuple = ('owm')
#         unit = "c"
#
#         API_deal.get_API_now(unit, command_list[0], history_list)
#         ```
#     - A 在 webapp.py 中尝试复现 API 调用
#         - I 这其中其实可分解成两步
#             - 01 输入城市,回车,返回指定天气信息
#             - 02 以 API 的调用结果代替指定天气
#         - Q  如何实现 01输入城市,回车,返回指定天气?
#             - I request 接收输入信息: request.args.get('key')
#                 - => `city = request.args.get('input_text')`
#             - X 不行,city 的内容为空,为 NONE
#                 - Q 如何获取搜索信息?
#                     - I request.args.get('key','')以前测试过是可以的,现在莫名失效,十分不解
#                     - Q 无论输入什么,获取的信息都是 NONE? 是否因为原来的方法为"get",url 有变化,而这个方法只能用来获取 url 的变量,现在变为 post 方法, url 不再变化就无效了呢?
#                         - A 查看官方文档
#                         - I 文档原文如下
#                             > args:A MultiDict with the parsed contents of the query string. (The part in the URL after the question mark).
#
#                             - 查询字符的复合字典,url中 ?之后的部分
#                             - => 确实, args 只能捕捉 url 的内容
#                         - Q 奇怪的地方:当 html 的 form 提交方法为 get 时,按钮就无法生效,而为 post 时, request.args.get()无法生效
#                         - A 查看 py103 的实现方式
#                         - I 使用 request.form['key'] 的方式调取数据
#                         - O 试着验证=>成功
#                         ```python
#                             elif 'query' in request.form.keys():
#                                 city = request.form['input_text']
#                                 weather_info= city
#                                 return render_template('Index.html',DisplayInfo=weather_info)
#                         ```
#                         - O 获取经验:
#                             - 具体:
#                                 - request.arg 只能获取 url? 后的数据
#                                 - request.from 可以获取任意 form 内的数据
#                             - 抽象:
#                                 - 对问题涉及对象的层级关系把握很重要, stuck 时可以试着从同级元素/或者上级元素中寻找突破口
#             - O 成功接收 city, 返回指定数据
#         - O 01 完成
#         - Q  如何实现 02 以 API 的调用结果代替指定天气?
#             - A 观察 API 调用代码
#             - I 有效代码片段如下
#             ```python
#             import API_deal
#             unit = "c"
#             history_list=[]
#             API_deal.get_API_now(unit, city, history_list)
#             ```
#         - A 尝试构建
#             - X `ModuleNotFoundError: No module named 'API_deal'`
#                 - A  google`python ModuleNotFoundError`
#                 - O from .modx import does_something
#                 - A `API_deal`=>`.API_deal`
#                 - X `ModuleNotFoundError: No module named 'utils'`
#                     - A API_deal 中
#                         - `utils.const_value` => `.utils.const_value`
#                     - O 不再报错
#             - O 报错解除
#             - A 搜索 `武汉`进行测试
#                 - X 服务端 API 响应成功,但是客户端浏览器没有显示
#                 - A 观察信息传递过程
#                     - I 发现 get_API_now 输出只有 print 没有 return ,所以只在服务端显示信息
#                     - A 进行改造
#                     ```python
#                     elif 'query' in request.form.keys():
#                         city = request.form['input_text']
#                         API_response=get_API_now(unit, city, history_list)
#                         weather_info=API_response[0]
#                         return render_template('Index.html',DisplayInfo=weather_info)
#                     ```
#             - O 测试成功,成功返回天气信息
#             - A 搜索错误信息进行测试
#             - X 无法返回错误信息
#                 - A 检查 API_deal.py
#                 - I 原先函数中的 print 要变成一个返回的对象,这就变得极为棘手,使得 api 错误处理部分的复用变得相当困难
#                 - O print 也是是个输出端口
#                 - O 最小函数模型
#                     - INPUT: 输入什么变量
#                     - DEAL: 做了什么动作
#                     - OUTPUT: 输出什么变量(print 也是输出)
#                     - => I/O 最好只有一个,容易实现复用
#                 - I 需要对 API 进行重构,使其容易复用
#                 - Q 如何重构以实现 API 容易复用?
#                     - A 观察 API 业务逻辑,看看能否优化成最简函数模型
#                         - I 关键在于 josn 文件处理与请求状态的重合.使得返回的信息混杂
#                         - A 观察ch2 的实现笔记,对业务逻辑进行梳理
#                             - I josn 的处理应该与状态信息的判断分离
#                     - A 对`get_API_now()` 进行了重构,统一输出为`Display_weather,history_list`:
#                     ```python
#                     def get_API_now(unit, city, history_list):
#                         """
#                         NowMode:发送 now_api 请求, 对响应进行判断处理,  显示天气, 添加至历史记录
#                         """
#                         print("get_API NOW begin!")
#
#                         seniverse_param = seniverse_params(unit, city)
#
#                         #weather_josn = get_response(seniverse_param, API_NOW)
#
#                         print("正在发生请求获取响应...")
#                         response = requests.get(
#                             API_NOW, params = seniverse_param, timeout = 20)  # 向 API 发送请求了
#
#                         if response.status_code == 200:  #请求成功, 打印相应天气信息并记录历史
#                             print("API 请求成功!")
#                             weather_josn = response.json()
#                             Display_weather = josn_now_deal(unit, weather_josn)
#                             history_list.append(Display_weather)
#
#                         elif response.status_code == 404:  #未找到城市信息, 用户重新输入
#                             Display_weather='''
#                                             对不起, 无该城市天气信息,\n
#                                             请检查您的输入, 或查询其他城市...
#                                             '''
#                         else:
#                             Display_weather='抱歉, 网络请求错误, 请重试...' #其他错误代码
#
#                         return Display_weather,history_list
#                     ```
#                     - O 运行成功,错误信息正常显示
#                     - W 该重构没有完成彻底,对 Daily 与 OWN 模式没有影响. 待 help 功能完成后,可进一步改进
#             - O 成功返回错误信息
#     - O API d调用成功,查询功能成功实现.
#
# - Q 如何实现历史功能
#     - I 问题的关键在于每一次点击 history 按钮, history_list 都会被重置
#     - Q history 作为哪种数据类型可以每次运行时不被重置呢?
#         -O history 为文件,文件读写就不会随着每次读写而重置
#     - Q 如何实现文件的读写功能?
#         - I 细分2步
#             - 点击 history 按钮,读取history 文件信息
#             - 查询成功时,将获取的天气信息加入到历史文件
#         - A 搜索 `python file`
#         - I =>[7. Input and Output — Python 3.6.4 documentation](https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files)
#             - A 测试文件的读取:
#             ```python
#             elif 'history' in request.form.keys():
#                 query_history =open('QueryHistory.txt','r')
#                 history_info =query_history.read()
#                 display_info =history_info
#             ```
#             - O 成功读取文件存储信息
#             - A 测试文件的写入
#             ```python
#             if response.status_code == 200:  #请求成功, 打印相应天气信息并记录历史
#                 print("API 请求成功!")
#                 weather_josn = response.json()
#                 Display_weather = josn_now_deal(unit, weather_josn)
#                 with open('QueryHistory.txt','a') as query_histroy:
#                     query_histroy.write(Display_weather)
#             ```
#             - O 测试成功
#             - W 如何在用户离开网站后将查询记录重置?
#                 - 或者是不同用户的登录状态?
#                 - => 或许可以考虑使用 josn 文件来读取,这样看 josn 就是为了解决 dict/list 等存储类型无法保存而出现的类似 file 的文件格式,既有 file 实体功能,又有 dict/list 的结构化功能.
#
#
# - O 至此,三种基本功能基本实现

# %% [markdown]
# ### 07 CSS 美化页面
#
# - Q: 如何使用 CSS 美化html? 有几种方式?
#     - A: DMN 官方文档找介绍
#     - I : =>[How CSS works - Learn web development | MDN](https://developer.mozilla.org/en-US/docs/Learn/CSS/Introduction_to_CSS/How_CSS_works)
#       -  properties 属性
#         "决定了内容呈现方式"
#       -  selector 选择器
#         "决定了应用目标呈现方式的内容"
#       - stylesheet  样式表
#         "包含了一组 CSS 规则"
#         -  a stylesheet is applied to the HTML using a <link> element
#         - A : 了解 link 标签
#             - I :[\<link\>: The External Resource Link element - HTML | MDN](https://developer.mozilla.org/en-US/docs/Web/HTML/Element/link)
#                 - 指定当前文件与外部资源的关系
#                 - 最常用来指定样式表 CSS
#                     - rel 关系的命名
#                     - type 指定未必资源格式
#                     - href url资源定位
#     - A: 实现一次简单的 css 渲染:将标题变成蓝色字
#          - I 参考 demo
#              ```html
#             <!DOCTYPE html>
#             <html>
#               <head>
#                 <meta charset="utf-8">
#                 <title>My CSS experiment</title>
#                 <link rel="stylesheet" href="style.css">
#               </head>
#               <body>
#                 <h1>Hello World!</h1>
#                 <p>This is my first CSS example</p>
#               </body>
#             </html>
#             ```
#             ```css
#             h1 {
#                   color: blue;
#                   background-color: yellow;
#                   border: 1px solid black;
#                 }
#
#             p {
#                   color: red;
#                 }
#             ```
#         - I 提取关键
#            ```html
#            <link rel="stylesheet" type="text/css" href="style.css">
#            ```
#         - A 尝试将标题变为蓝色
#             - A 平级路径创建文件夹 `static`,创建文件`css/style.css`
#             - 编辑 `style.css` 文件
#             ```css
#             h1{
#                 color: blue;
#             }
#             ```
#             - A 在html 的`<head>`中添加
#             ```css
#             	<link rel="stylesheet" type="text/css" href="static/css/style.css">
#             ```
#             - O 成功将标题变蓝
#
#  - O 美化永无止境,知道 css 如何作用于 html 文件即可

# %% [markdown]
# ###  07 WEB 应用适配移动端
#
# - Q 如何让 web 程序适配移动端?
#     - A 看开智卡片提示
#     - I Bootstrap 框架
#         - Q 为什么选择 Bootstrap 框架?
#             > I 最流行的用于开发响应式,移动优先的的 web 项目的
#             - HTML,CSS,和 JS 框架
# - Q 如何使用 Bootstrap 框架?
#     - A 查看官方文档=>
#         - [Introduction · Bootstrap](http://getbootstrap.com/docs/4.0/getting-started/introduction/)
#     - I 应用 Bp 的 css 样式表
#         ```html
#         <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
#         ```
#     - I viewport 是移动设备优先响应式的关键
#         >To ensure proper rendering and touch zooming for all devices, add the responsive viewport meta tag to your <head>.
#         ```html
#         <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#         ```
#     - I Demo 如下
#
#     ```html
#     <!doctype html>
# <html lang="en">
#   <head>
#     <!-- Required meta tags -->
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
#     <!-- Bootstrap CSS -->
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/css/bootstrap.min.css" integrity="sha384-Gn5384xqQ1aoWXA+058RXPxPg6fy4IWvTNh0E263XmFcJlSAwiGgFAW/dAiS6JXm" crossorigin="anonymous">
#
#     <title>Hello, world!</title>
#   </head>
#   <body>
#     <h1>Hello, world!</h1>
#
#     <!-- Optional JavaScript -->
#     <!-- jQuery first, then Popper.js, then Bootstrap JS -->
#     <script src="https://code.jquery.com/jquery-3.2.1.slim.min.js" integrity="sha384-KJ3o2DKtIkvYIK3UENzmM7KCkRr/rE9/Qpg6aAZGJwFDMVNA/GpGFF93hXpG5KkN" crossorigin="anonymous"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js" integrity="sha384-ApNbgh9B+Y1QKtv3Rn7W3mgPxhU9K/ScQsAP7hUibX39j7fakFPskvXusvfa0b4Q" crossorigin="anonymous"></script>
#     <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js" integrity="sha384-JZR6Spejh4U02d8jOt6vLEHfe/JQGiRRSQQxSfFWpi1MquVdAyjUar5+76PVCmYl" crossorigin="anonymous"></script>
#   </body>
# </html>
#     ```
#
# - O

# %% [markdown]
# ## KeyPoint
#
# - WSGI
# - CS/BS架构
# - Http 请求原理
#     - 告诉服务器用户相对页面做什么动作
# - 路由@
# - 修饰器: route()
#     - bind a function to a URL
#     - make certain parts of the URL dynamic
#     - and attach multiple rules to a function.
# - 重定向行为(Redirection Behavior)

# %% [markdown]
# ## CommandSet

# %% [markdown]
# - 打开 flask app
#     - `cd <app.py 所在层级>`
#     - `export FLASK_APP=<appname.py>`
#     - `export FLASK_DEBUG=1`
#     - `flask run`

# %% [markdown]
# ## Question
#
# - Q.web 开发基本结构是什么?
# - Q.你为项目选择怎样的web框架?有什么值得借鉴的原则/要领吗?
#
# - Q.web app文件通常包括哪些部分,调用的原理是什么?
#     - py
#     - 静态页面
#     - 模板
#     - css/JavaScript
#     - ...
# - Q.如何降低程序复杂度?
#
# - Q.module 与 package 的区别?
#     - 触发:[Quickstart — Flask Documentation (0.12)](http://flask.pocoo.org/docs/0.12/quickstart/#rendering-templates)
#     >So if your application is a module, this folder is next to that module, if it’s a package it’s actually inside your package
#     - 回答:=>[What's the difference between a Python module and a Python package? - Stack Overflow](https://stackoverflow.com/questions/7948494/whats-the-difference-between-a-python-module-and-a-python-package)
#     > There is only one class for modules/packages in Python. Package is just a module with a `__path__` attribute.
#     >
#     >Packages are modules too. They are just packaged up differently; they are formed by the combination of a directory plus `__init__.py` file. They are modules that can contain other modules.
#     - 其他:
#         - `__ int__.py` 所在文件层级(或次一级)可作为 module 被 import, 次二级就 import 失败.
#
# - Q. 如何控制开发环境,形成干净的 `requirements.txt`?
#     - 触发:[Py101-004/chap3_note.md at master · JeetChan/Py101-004](https://github.com/JeetChan/Py101-004/blob/master/Chap3/note/chap3_note.md#%E6%90%AD%E5%BB%BA%E5%BC%80%E5%8F%91%E7%8E%AF%E5%A2%83)
#         - 为应用开发虚拟环境,保证干净的开发环境
#         - 生成 requirements.txt 文件:`pip freeze >requirements.txt`
#         - 对比发现自己的环境极其复杂,不相关的包也被列了出来
#         - 混杂的环境让我意识到割离不同开发环境的必要性
#     - 参考:
#         - ...[w]

# %% [markdown]
# ## Timelog

# %% [markdown]
# - 170913
#     - flask install  `20m`
#     - flask mvp  `45m` `!WARN: 细节过渡深究`
# - 170927
#     - 重新续上思路,思考 50min
#     - 卡顿,拿纸笔重新思考 `1h` `!WARN:陷入概念定义的探寻,缺少代码验`
# - 171003
#     - 重新梳理思路 `20m`
#     - 文件结构 `42m` `!WARN: 编写的时间过长`

# %% [markdown]
# - 171004
#     - html 编写 1h `!WARN: 缺少问题的驱动`
# - 171023
#     - html 基本页面编写 20m

# %% [markdown]
# - 171224
#     - 重新启动项目 '25m'
#     - 梳理思路 '25m'
#     - 前后端交互 '3h'
# - 171225
#     - [x] 前后端交互 '1h'
